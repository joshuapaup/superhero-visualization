# %% [markdown]
# ### IMPORTANT: This notebook file will not run unless the .ipynb file and the supeheroData.csv are in the same folder!

# %% [markdown]
# # Marvel-DC Comics data plot project skeleton

# %% [markdown]
# ### DC_comics_skeleton created by Ricarose Roque. Pandas matplotlib skeleton created by Wendy Norris and plots created by Stephen Barton as a demo for Summer INFO 1201.

# %% [markdown]
# ##### Step 1: Import the pandas and matplotlib libraries into Jupyter Notebook. <font color=red><-- Check out the new library</font>

# %% [markdown]
# This command provides routine instructions to Python on how to handle the data in the spreadsheet. We abbreviate Pandas as pd and Numpy as np for faster typing/cleaner looking code. To plot the data, we'll use a new library called matplotlib and a sublibrary called pyplot.
#
# With matplotlib, it needs two particular directions.
#     1. matplotlib inline to display the plots inside the Jupyter Notebook cell.
#     2. plt.rcParams["figure.figsize"] = (x, y) to set the size for all the plots.
#
# Click <i>Shift-Enter</i> through the import line. It won't look to you like anything happened but Jupyter knows.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (8, 6)

# %% [markdown]
# ##### Step 2: Now we set up pandas to open the csv file.

# %% [markdown]
# First, we'll tell Jupyter to use some of the built-in instructions from the imported Python libraries to read the file.
#
# We'll assign a new name to the csv file to make it easier to differentiate between the file on our desktops and the one we're working with in Jupyter.
#
# Next, use the pd.read_csv command to tell Jupyter to take all the data, read it, and copy it into this new variable called "superheroes". Finally, on the same line, we add the command to <i>parse_dates</i>. This is a nifty trick by Pandas to standardize the way the YEAR column in the csv file is formatted in Jupyter so that Python understands that 2017 is a year and not just a <i>string</i> or <i>integer</i>. This will make it easier for us to access and explore the data.
#
# Again, when you <i>Shift-Enter</i> through this next cell, it won't look like anything happened.

# %%
superheroes = pd.read_csv("superheroData.csv", parse_dates = ["FIRST_YEAR"])

# %% [markdown]
# ##### Step 3: Let's print a few lines of the superheroes list to make sure Jupyter read it correctly.

# %% [markdown]
# Pandas makes it super easy to print a nice dataframe to look at the <i>head</i> or the first 5 rows of the spreadsheet to check for any import errors.

# %%
superheroes.head()
# Out:
#   UNIVERSE page_id                                 name  \
# 0   MARVEL      ND         Artificial being (Earth-616)
# 1   MARVEL      ND                 Batch-13 (Earth-616)
# 2   MARVEL      ND  Blockers Bots (Hazards) (Earth-616)
# 3   MARVEL      ND       Carnage (Symbiote) (Earth-616)
# 4   MARVEL      ND                 Changers (Earth-616)
#
#                                urlslug                ID           ALIGN  \
# 0         Artificial_being_(Earth-616)                ND  Bad Characters
# 1                 Batch-13_(Earth-616)   Secret Identity  Bad Characters
# 2  Blockers_Bots_(Hazards)_(Earth-616)  No Dual Identity  Bad Characters
# 3       Carnage_(Symbiote)_(Earth-616)   Public Identity  Bad Characters
# 4                 Changers_(Earth-616)   Secret Identity  Bad Characters
#
#   IS_AVENGER AVENGER_STATUS AVENGER_YEAR        EYES     HAIR  \
# 0         NO             ND           ND          ND  No Hair
# 1         NO             ND           ND    Red Eyes  No Hair
# 2         NO             ND           ND  Green Eyes  No Hair
# 3         NO             ND           ND  White Eyes  No Hair
# 4         NO             ND           ND          ND  No Hair
#
#                   SEX                SEXUALITY              ALIVE APPEARANCES  \
# 0  Agender Characters  Heterosexual Characters  Living Characters           2
# 1  Agender Characters  Heterosexual Characters  Living Characters          ND
# 2  Agender Characters  Heterosexual Characters  Living Characters           1
# 3  Agender Characters  Heterosexual Characters  Living Characters          61
# 4  Agender Characters  Heterosexual Characters  Living Characters           1
#
#   FIRST_MONTH FIRST_YEAR DECEASED RESURRECTED
# 0   September       1966       ND          ND
# 1    February       1995       ND          ND
# 2          ND         ND       ND          ND
# 3       March       1992       ND          ND
# 4         May       1971       ND          ND

# %% [markdown]
# #### Step 4: Now, we can get down to business and begin to explore the data with regular old Python code. Pandas, NumPy and Matplotlib are doing all the work behind the scenes.
#
# Unlike some of the code we've reviewed in class, this data analysis is much more streamlined by using the Python libraries to do the heavy lifting. We don't need to use the <i>"def main()"</i> and <i>"def"</i> functions to define the new variables.

# %% [markdown]
# #### Step 5: Following are some examples of Python code calling different data insights from the spreadsheet on your desktop and plotting data visualizations.

# %% [markdown]
# ## Plot #1: Total number of characters by gender.
# ### This is a fairly simple, straightforward query that would be well represented by a bar chart, horizontal bar chart or pie chart. Nothing fancy. Mostly gets the job done but there's a couple of problems.

# %%
sex_counts = superheroes["SEX"].value_counts()
print(sex_counts)

#here it is as a bar chart. 
#Look carefully to detect the coding differences between sex_counts.plot lines of code for pie vs bar chart. 
sex_counts.plot(kind="bar", subplots=True, fontsize=14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)

plt.show()

#here it is as a pie chart 
sex_counts.plot(kind="pie", autopct="%1.0f%%", subplots=True, fontsize=14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)

#plt.show displays the plot and is the equivalent of a print() statement
plt.show()
# Out:
# Male Characters           16521
# Female Characters          5853
# ND                          978
# Agender Characters           45
# Genderless Characters        20
# Genderfluid Characters        2
# Transgender Characters        1
# Name: SEX, dtype: int64

# %% [markdown]
# ### Here, I'm customizing the look of my pie chart a bit. Adding custom colors, deleting the unnecessary "SEX" label on the left side of the chart, and forcing the pie to be a little more round. But there's still a problem with the tiny pie slice labels overlapping on the right side.

# %%
# add some custom colors from this pre-defined lists: 

# individual colors that you define as a list - https://matplotlib.org/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py
my_colors = ["slategrey", "lavender", "firebrick", "gold"]

# colormaps that are pre-made - http://scipy.github.io/old-wiki/pages/Cookbook/Matplotlib/Show_colormaps


sex_counts = superheroes["SEX"].value_counts()
sex_counts.plot(kind = "pie", colormap = "Spectral", autopct = "%1.0f%%", subplots = True, fontsize = 14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)

#get rid of y axis label SEX - http://stackoverflow.com/questions/34094596/python-matplotlib-pyplot-pie-charts-how-to-remove-the-label-on-the-left-side
plt.axes().set_ylabel('')

#make plot have even axes so the pie chart is perfectly circular
plt.axis("equal")

plt.show()

#These modifications also help make the bar chart look nicer and more readable

sex_counts = superheroes["SEX"].value_counts()
sex_counts.plot(kind = "bar", color = [my_colors], fontsize = 14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)

plt.show()
# Out:
# /Users/joshuapaup/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f3c63bb3e6ea> in <module>()
#      22
#      23 sex_counts = superheroes["SEX"].value_counts()
# ---> 24 sex_counts.plot(kind = "bar", color = [my_colors], fontsize = 14)
#      25 plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)
#      26
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#    1263                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1264                                   start=start, label=label,
# -> 1265                                   log=self.log, **kwds)
#    1266             self._add_legend_handle(rect, label, index=i)
#    1267
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1207     @classmethod
#    1208     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1209         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1210
#    1211     @property
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2242
#    2243         linewidth = itertools.cycle(np.atleast_1d(linewidth))
# -> 2244         color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2245                                 # Fallback if color == "none".
#    2246                                 itertools.repeat([0, 0, 0, 0]))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     265     result = np.empty((len(c), 4), float)
#     266     for i, cc in enumerate(c):
# --> 267         result[i] = to_rgba(cc, alpha)
#     268     return result
#     269
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     217         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     218         # Test dimensionality to reject single floats.
# --> 219         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     220     # Return a tuple to prevent the cached value from being modified.
#     221     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: ['slategrey', 'lavender', 'firebrick', 'gold']

# %% [markdown]
# ### To fix the slice issue, I actually need to go back into my data. I can do one of two things:
#
# > • use the .drop method to exclude those SEX categories from the analysis (but I'll have to account for that in the narrative).<br>
# > • create an "other" category that combines, or in Pandas terminology "bins", the Agender, Genderless,Transgender, etc., categories together.
#
# The second option is a more complicated process which we haven't learned so we won't get into here. Suffice to say, it can be done.

# %%
# drop all of the other SEX categories other than Male, Female and ND

genderA = superheroes.drop(superheroes[superheroes.SEX == "Agender Characters"].index)
genderGL = genderA.drop(genderA[genderA.SEX == "Genderless Characters"].index)
genderGF = genderGL.drop(genderGL[genderGL.SEX == "Genderfluid Characters"].index)
genderT = genderGF.drop(genderGF[genderGF.SEX == "Transgender Characters"].index)
genderMF = genderT

# add some custom colors from this pre-defined list: 
# https://matplotlib.org/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py
my_colors = ["slategrey", "lavender", "firebrick", "gold"]

sex_counts = genderMF["SEX"].value_counts()
sex_counts.plot(kind = "pie", colormap = "Spectral", autopct = "%1.0f%%", subplots = True, fontsize = 14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)

#get rid of y axis label SEX - http://stackoverflow.com/questions/34094596/python-matplotlib-pyplot-pie-charts-how-to-remove-the-label-on-the-left-side
plt.axes().set_ylabel('')

#make plot have even axes so the pie chart is perfectly circular
plt.axis("equal")

plt.show()

#Dropping the other SEX categories also helps make the bar chart look better too

sex_counts = genderMF["SEX"].value_counts()
sex_counts.plot(kind = "bar", color = [my_colors], fontsize = 14)
plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)
plt.xticks(rotation = 0, fontsize = 10)
plt.yticks(fontsize = 12)
plt.xlabel("Type of Character", fontsize = 14)
plt.ylabel("Number of Characters", fontsize = 14)


plt.show()
# Out:
# /Users/joshuapaup/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d3f8e793f8c7> in <module>()
#      26
#      27 sex_counts = genderMF["SEX"].value_counts()
# ---> 28 sex_counts.plot(kind = "bar", color = [my_colors], fontsize = 14)
#      29 plt.title("Number of Marvel and DC Characters by Sex", fontsize = 18)
#      30 plt.xticks(rotation = 0, fontsize = 10)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#    1263                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1264                                   start=start, label=label,
# -> 1265                                   log=self.log, **kwds)
#    1266             self._add_legend_handle(rect, label, index=i)
#    1267
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1207     @classmethod
#    1208     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1209         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1210
#    1211     @property
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2242
#    2243         linewidth = itertools.cycle(np.atleast_1d(linewidth))
# -> 2244         color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2245                                 # Fallback if color == "none".
#    2246                                 itertools.repeat([0, 0, 0, 0]))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     265     result = np.empty((len(c), 4), float)
#     266     for i, cc in enumerate(c):
# --> 267         result[i] = to_rgba(cc, alpha)
#     268     return result
#     269
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     217         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     218         # Test dimensionality to reject single floats.
# --> 219         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     220     # Return a tuple to prevent the cached value from being modified.
#     221     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: ['slategrey', 'lavender', 'firebrick', 'gold']

# %% [markdown]
# ## Plot #2: This is another basic graph based on the Marvel-DC skeleton that visualizes characteristics across time

# %%
appearance_by_sex = pd.crosstab(superheroes['FIRST_YEAR'], superheroes['ALIGN'])
appearance_by_sex.plot()
plt.title("Number of New Characters by Year")
plt.xlabel("Years", fontsize = 14)
plt.ylabel("Number of Characters", fontsize = 14)
plt.show()

# %% [markdown]
# ## Plot #3: A crosstab of characters.
# ### This kind of query is best suited as a bar chart — vertical or horizontal.

# %%
my_colors = ["slategrey", "lavender", "firebrick", "gold"]

# here's a typical bar chart
alive_or_dead = pd.crosstab(superheroes["ALIGN"], superheroes["ALIVE"])
alive_or_dead.plot(kind = 'bar')
plt.title("Number of Characters Dead and Alive by Alignment Type", fontsize = 18)
plt.xticks(rotation = 20, fontsize = 10)
plt.yticks(fontsize = 12)
plt.xlabel("Type of Character", fontsize = 14)
plt.ylabel("Number of Characters", fontsize = 14)
plt.show()


# here's a horizontal bar chart. Notice that we need to change the x- and ylabels. 
alive_or_dead = pd.crosstab(superheroes["ALIGN"], superheroes["ALIVE"])
alive_or_dead.plot(kind = 'barh')
plt.title("Number of Characters Dead and Alive by Alignment Type", fontsize = 18)
plt.xticks(rotation = 0, fontsize = 10)
plt.yticks(fontsize = 12)
plt.xlabel("Number of Characters", fontsize = 14)
plt.ylabel("Type of Character", fontsize = 14)

plt.show()

# %% [markdown]
# ## Plot #4: Another crosstab with more control over the plot layout
# ### But check out the last bar representing Reformed Criminals' identities. What's going on there? Is it a data error?

# %%
identity_count = pd.crosstab(superheroes['ALIGN'], superheroes['ID'])
identity_count.plot(kind = 'bar', stacked = True)
plt.title("Type of Character Identity", fontsize = 20)
plt.xticks(rotation=-10, fontsize = 10)
plt.yticks(fontsize = 10)
plt.xlabel("Type of Character", fontsize = 16)
plt.ylabel("Number of Characters", fontsize = 16)
plt.show()

# %% [markdown]
# ### It's not a data error but just a value with a very low number in comparison to the others. Consider removing it from the data query and using your narrative to mention that there are only a few characters with unknown identities.
#
# ### Another option is to use a different chart type (like this area chart) that helps to illustrate how few reformed criminals there are.

# %%
identity_count = pd.crosstab(superheroes['ALIGN'], superheroes['ID'])
identity_count.plot.area();
plt.title("Type of Character Identity", fontsize = 20)
plt.xticks(rotation=0, fontsize = 10)
plt.yticks(fontsize = 10)
plt.xlabel("Type of Character", fontsize = 16)
plt.ylabel("Number of Characters", fontsize = 16)
# Out:
# Text(0,0.5,'Number of Characters')

# %% [markdown]
# ## Plot #5: Another view of the chart above as a regular bar chart.
# ### But we still seem to have a problem with the last character type. And the plot layout could use a little help. What would you do?

# %%
identity_count = pd.crosstab(superheroes['ALIGN'], superheroes['ID'])
identity_count.plot(kind= 'bar')
plt.title('Type of ID')
plt.show()

# %% [markdown]
# ## Plot #6: A plot that's fighting itself to the death
# ### Chalk this up to a great idea that's not actually plottable. How do you plot unique hero names that can't be grouped together, like character types (Good, Bad, Neutral, etc.)? Hint: Not very well.

# %%
superhero_names = superheroes.drop(superheroes[superheroes.APPEARANCES == "ND"].index)
pop_heroes = superhero_names.sort_values(by = "APPEARANCES", ascending = False)

print(pop_heroes)
# Out:
#       UNIVERSE page_id                                 name  \
# 1577    MARVEL      ND             Yuriko Oyama (Earth-616)
# 12206   MARVEL      ND                 Acroyear (Earth-616)
# 13378   MARVEL      ND           Elijah Bradley (Earth-616)
# 13765   MARVEL      ND    Grand Vizier (Asgard) (Earth-616)
# 11024   MARVEL      ND             Louise Grant (Earth-616)
# 22804   MARVEL      ND              Pyreus Kril (Earth-616)
# 11382       DC    1869            Natasha Irons (New Earth)
# 11866       DC    2780                  Stealth (New Earth)
# 6964    MARVEL      ND            Phillip Urich (Earth-616)
# 10428   MARVEL      ND             Frankie Raye (Earth-616)
# 14253       DC   69043               Jan Haasan (New Earth)
# 11020       DC    4170          Lorraine Reilly (New Earth)
# 9812    MARVEL      ND             Anya Corazon (Earth-616)
# 6660        DC    1623             Noah Kuttler (New Earth)
# 10726   MARVEL      ND          Jimaine Szardos (Earth-616)
# 10841       DC    1797        Katherine Spencer (New Earth)
# 13181   MARVEL      ND       Delroy Garrett Jr. (Earth-616)
# 3386        DC    1903                  Despero (New Earth)
# 21462   MARVEL      ND            Victoria Hand (Earth-616)
# 9921    MARVEL      ND             Bethany Cabe (Earth-616)
# 10575       DC    2085         Hippolyta Trevor (New Earth)
# 11108   MARVEL      ND          Margaret Carter (Earth-616)
# 1417        DC   16693        Tef\u00e9 Holland (New Earth)
# 22085   MARVEL      ND                    Ghost (Earth-616)
# 18555   MARVEL      ND         Clay Quartermain (Earth-616)
# 9632    MARVEL      ND            Abigail Brand (Earth-616)
# 21020   MARVEL      ND               Jill Stacy (Earth-616)
# 10009   MARVEL      ND            Carlie Cooper (Earth-616)
# 5076        DC    1851    Jeffrey Franklin Burr (New Earth)
# 12263       DC    1459               Alan Scott (New Earth)
# ...        ...     ...                                  ...
# 17606       DC  205312                  Joan Ng (New Earth)
# 4134    MARVEL      ND               Gale Brown (Earth-616)
# 17659       DC  211517         Lady Nightingale (New Earth)
# 4101    MARVEL      ND        Fritz von Arnheim (Earth-616)
# 8690    MARVEL      ND             Victor Avery (Earth-616)
# 4102    MARVEL      ND           Fritz von Bock (Earth-616)
# 17697   MARVEL      ND            Lucy (Mutant) (Earth-616)
# 4105        DC  186253               Front Page (New Earth)
# 4108    MARVEL      ND                    Fungi (Earth-616)
# 12041   MARVEL      ND                    Vanza (Earth-616)
# 17692   MARVEL      ND                Lisa Skye (Earth-616)
# 17690   MARVEL      ND     Lisa Beth Harrington (Earth-616)
# 17689   MARVEL      ND             Lisa Beckman (Earth-616)
# 17688   MARVEL      ND                    Linga (Earth-616)
# 17685   MARVEL      ND              Linda Brown (Earth-616)
# 12044   MARVEL      ND      Vector (Ascendants) (Earth-616)
# 4119    MARVEL      ND                    Gaark (Earth-616)
# 17660       DC  211779              Lady Voodoo (New Earth)
# 4121    MARVEL      ND             Gabby Harris (Earth-616)
# 4122    MARVEL      ND             Gabriel Gant (Earth-616)
# 4124    MARVEL      ND            Gabriel Mason (Earth-616)
# 8689    MARVEL      ND                   Victor (Earth-616)
# 17673   MARVEL      ND            Leda Fontaine (Earth-616)
# 17672       DC   60689              Layla Adams (New Earth)
# 8688    MARVEL      ND       Vice (Power Tools) (Earth-616)
# 4129    MARVEL      ND  Gaines (Quiz Show Host) (Earth-616)
# 17668       DC    7566              Laura Klein (New Earth)
# 8686    MARVEL      ND              Vice (Grip) (Earth-616)
# 17662   MARVEL      ND   Langley Saint-Margaret (Earth-616)
# 3667        DC   54312          Ebeneezer Badde (New Earth)
#
#                                    urlslug                ID  \
# 1577              Yuriko_Oyama_(Earth-616)   Secret Identity
# 12206                 Acroyear_(Earth-616)  No Dual Identity
# 13378           Elijah_Bradley_(Earth-616)   Secret Identity
# 13765    Grand_Vizier_(Asgard)_(Earth-616)   Secret Identity
# 11024             Louise_Grant_(Earth-616)   Secret Identity
# 22804              Pyreus_Kril_(Earth-616)   Secret Identity
# 11382            Natasha_Irons_(New_Earth)   Public Identity
# 11866                  Stealth_(New_Earth)   Secret Identity
# 6964             Phillip_Urich_(Earth-616)   Secret Identity
# 10428             Frankie_Raye_(Earth-616)   Secret Identity
# 14253               Jan_Haasan_(New_Earth)   Public Identity
# 11020          Lorraine_Reilly_(New_Earth)   Secret Identity
# 9812              Anya_Corazon_(Earth-616)   Public Identity
# 6660              Noah_Kuttler_(New_Earth)   Public Identity
# 10726          Jimaine_Szardos_(Earth-616)   Secret Identity
# 10841        Katherine_Spencer_(New_Earth)   Secret Identity
# 13181       Delroy_Garrett_Jr._(Earth-616)   Secret Identity
# 3386                   Despero_(New_Earth)   Public Identity
# 21462            Victoria_Hand_(Earth-616)  No Dual Identity
# 9921              Bethany_Cabe_(Earth-616)  No Dual Identity
# 10575         Hippolyta_Trevor_(New_Earth)   Secret Identity
# 11108          Margaret_Carter_(Earth-616)   Public Identity
# 1417         Tef%C3%A9_Holland_(New_Earth)                ND
# 22085                    Ghost_(Earth-616)   Secret Identity
# 18555         Clay_Quartermain_(Earth-616)  No Dual Identity
# 9632             Abigail_Brand_(Earth-616)   Secret Identity
# 21020               Jill_Stacy_(Earth-616)   Public Identity
# 10009            Carlie_Cooper_(Earth-616)  No Dual Identity
# 5076     Jeffrey_Franklin_Burr_(New_Earth)   Secret Identity
# 12263               Alan_Scott_(New_Earth)   Secret Identity
# ...                                    ...               ...
# 17606                  Joan_Ng_(New_Earth)   Public Identity
# 4134                Gale_Brown_(Earth-616)   Public Identity
# 17659         Lady_Nightingale_(New_Earth)   Secret Identity
# 4101         Fritz_von_Arnheim_(Earth-616)   Secret Identity
# 8690              Victor_Avery_(Earth-616)   Secret Identity
# 4102            Fritz_von_Bock_(Earth-616)   Secret Identity
# 17697            Lucy_(Mutant)_(Earth-616)                ND
# 4105                Front_Page_(New_Earth)                ND
# 4108                     Fungi_(Earth-616)   Secret Identity
# 12041                    Vanza_(Earth-616)   Public Identity
# 17692                Lisa_Skye_(Earth-616)                ND
# 17690     Lisa_Beth_Harrington_(Earth-616)   Public Identity
# 17689             Lisa_Beckman_(Earth-616)                ND
# 17688                    Linga_(Earth-616)   Public Identity
# 17685              Linda_Brown_(Earth-616)   Secret Identity
# 12044      Vector_(Ascendants)_(Earth-616)   Secret Identity
# 4119                     Gaark_(Earth-616)                ND
# 17660              Lady_Voodoo_(New_Earth)   Secret Identity
# 4121              Gabby_Harris_(Earth-616)                ND
# 4122              Gabriel_Gant_(Earth-616)                ND
# 4124             Gabriel_Mason_(Earth-616)                ND
# 8689                    Victor_(Earth-616)                ND
# 17673            Leda_Fontaine_(Earth-616)                ND
# 17672              Layla_Adams_(New_Earth)   Secret Identity
# 8688        Vice_(Power_Tools)_(Earth-616)   Secret Identity
# 4129   Gaines_(Quiz_Show_Host)_(Earth-616)   Public Identity
# 17668              Laura_Klein_(New_Earth)   Secret Identity
# 8686               Vice_(Grip)_(Earth-616)                ND
# 17662   Langley_Saint-Margaret_(Earth-616)                ND
# 3667           Ebeneezer_Badde_(New_Earth)   Secret Identity
#
#                     ALIGN IS_AVENGER AVENGER_STATUS AVENGER_YEAR         EYES  \
# 1577       Bad Characters         NO             ND           ND   Brown Eyes
# 12206     Good Characters         NO             ND           ND    Grey Eyes
# 13378     Good Characters         NO             ND           ND   Brown Eyes
# 13765     Good Characters         NO             ND           ND           ND
# 11024     Good Characters         NO             ND           ND    Blue Eyes
# 22804  Neutral Characters         NO             ND           ND   White Eyes
# 11382     Good Characters         NO             ND           ND   Brown Eyes
# 11866     Good Characters         NO             ND           ND    Pink Eyes
# 6964       Bad Characters         NO             ND           ND   Green Eyes
# 10428     Good Characters         NO             ND           ND    Blue Eyes
# 14253     Good Characters         NO             ND           ND           ND
# 11020     Good Characters         NO             ND           ND    Blue Eyes
# 9812      Good Characters         NO             ND           ND   Brown Eyes
# 6660       Bad Characters         NO             ND           ND   Green Eyes
# 10726     Good Characters         NO             ND           ND    Blue Eyes
# 10841     Good Characters         NO             ND           ND    Blue Eyes
# 13181     Good Characters         NO             ND           ND   Brown Eyes
# 3386       Bad Characters         NO             ND           ND  Yellow Eyes
# 21462  Neutral Characters         NO             ND           ND   Hazel Eyes

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-92c5db31f595> in <module>()
#       2 pop_heroes = superhero_names.sort_values(by = "APPEARANCES", ascending = False)
#       3
# ----> 4 ax = pop_heroes.iloc[:10].plot(kind = "barh")
#       5 ax = pop_heroes.plot(kind = "barh")
#       6 ax.invert_yaxis()
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     241     def generate(self):
#     242         self._args_adjust()
# --> 243         self._compute_plot_data()
#     244         self._setup_subplots()
#     245         self._make_plot()
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     350         if is_empty:
#     351             raise TypeError('Empty {0!r}: no numeric data to '
# --> 352                             'plot'.format(numeric_data.__class__.__name__))
#     353
#     354         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# ## Plot #7: Superheroes by era
# ### Let's try a fancier look at date ranges. First, I want to narrow my data down to only characters who appeared in the 1960s vs 1970s.

# %%
# I want to include only superheroes whose first appearance year is between 1960 - 1969
superheroes_hippie_era = (superheroes["FIRST_YEAR"] >= "1960") & (superheroes["FIRST_YEAR"] <= "1969")
superheroes_hippies = (superheroes[superheroes_hippie_era])

sixties_sex_counts = superheroes_hippies["FIRST_YEAR"].value_counts()
sixties_sex_total = superheroes_hippies["SEX"].count()

print("Superheroes during the 1960s: ")
print(sixties_sex_counts)
print(sixties_sex_total)

# This is an empty print statement to add a line
print()

# Next, I take the new dataframe called genderMFND and further modify it. 
# I want to include only superheroes whose first appearance year is between 1970 - 1979

superheroes_motown_era = (superheroes["FIRST_YEAR"] >= "1970") & (superheroes["FIRST_YEAR"] <= "1979")
superheroes_motowns = (superheroes[superheroes_motown_era])
#seventies_sex_counts_sort = superheroes_motowns.sort_values(by = "FIRST_YEAR", ascending = True, inplace = True)

seventies_sex_counts = superheroes_motowns["FIRST_YEAR"].value_counts()
seventies_sex_total = superheroes_motowns["SEX"].count()

print("Superheroes during the 1970s: ")
print(seventies_sex_counts)
print(seventies_sex_total)

# In this step, I need to knit together the two dataframes I created with the pd.Series method
# The index defines the decades for the x-axis of the chart

best_era = pd.Series([sixties_sex_total, seventies_sex_total], index = ["1960-1969", "1970-1979"])

# add some custom colors
my_colors = ["slategrey", "lavender", "firebrick", "gold"]

# set the bar chart customizations
best_era.plot(kind = "bar", stacked = True, color = [my_colors])

plt.xticks(rotation = 0, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Decade of First Appearance", fontsize = 16)
plt.ylabel("Number of Characters", fontsize = 16)

plt.show()
# Out:
# Superheroes during the 1960s:
# 1965    234
# 1963    229
# 1964    211
# 1968    206
# 1966    203
# 1967    183
# 1969    163
# 1962    152
# 1961    138
# 1960     79
# Name: FIRST_YEAR, dtype: int64
# 1798
#
# Superheroes during the 1970s:
# 1976    357
# 1977    346
# 1975    329
# 1973    269
# 1979    269
# 1978    260
# 1974    258
# 1972    245
# 1971    179
# 1970    161
# Name: FIRST_YEAR, dtype: int64
# 2673

# %% [markdown]
# ## Plot #8: Superheroes by era and sex
# ### Now, I want to display the characters by decade according to their SEX. This version isn't working yet. : (

# %%
# Here I'm dropping the unneeded SEX types in order to narrow down the dataframe to only Male, Female and ND. 
# I need to do this step multiple times in order to filter out each SEX type
genderA = superheroes.drop(superheroes[superheroes.SEX == "Agender Characters"].index)
genderGL = genderA.drop(genderA[genderA.SEX == "Genderless Characters"].index)
genderGF = genderGL.drop(genderGL[genderGL.SEX == "Genderfluid Characters"].index)
genderT = genderGF.drop(genderGF[genderGF.SEX == "Transgender Characters"].index)

# The new dataframe is renamed genderMFND (Male, Female, ND) so it's more descriptive of the data. 
# It is the remainder from all the drops ending with genderT 
genderMFND = genderT

sex_counts = genderMFND["SEX"].value_counts()
print("Male and Female Superheroes All Years")
print(sex_counts)

# Next, I take the new dataframe called genderMFND and further modify it. 
# I want to include only superheroes whose first appearance year is between 1960 - 1969
superheroes_hippie_era = (genderMFND["FIRST_YEAR"] >= "1960") & (genderMFND["FIRST_YEAR"] <= "1969")
superheroes_hippies = (genderMFND[superheroes_hippie_era])

sixties_sex_total = superheroes_hippies["SEX"].count()
sixties_sex_counts = superheroes_hippies["SEX"].value_counts()


print("\nSuperheroes during the 1960s: ")
print(sixties_sex_total)
print(sixties_sex_counts)

# Next, I take the dataframe called genderMFND and modify it again. 
# I want to include only superheroes whose first appearance year is between 1970 - 1979

superheroes_motown_era = (genderMFND["FIRST_YEAR"] >= "1970") & (genderMFND["FIRST_YEAR"] <= "1979")
superheroes_motowns = (genderMFND[superheroes_motown_era])
#seventies_sex_counts_sort = superheroes_motowns.sort_values(by = "FIRST_YEAR", ascending = True, inplace = True)

seventies_sex_total = superheroes_motowns["SEX"].count()
seventies_sex_counts = superheroes_motowns["SEX"].value_counts()

print("\nSuperheroes during the 1970s: ")
print(seventies_sex_total)
print(seventies_sex_counts)

sixties_sex_counts.plot(kind = "bar", stacked = True, color = [my_colors], subplots = True)
plt.xticks(rotation = 0, fontsize = 12)
plt.yticks(fontsize = 12)
plt.title("First Appeared in the 1960s", fontsize = 16)
plt.xlabel("Sex of Character", fontsize = 14)
plt.ylabel("Number of Characters", fontsize = 14)

plt.show()

seventies_sex_counts.plot(kind = "bar", stacked = True, color = [my_colors], subplots = True)
plt.xticks(rotation = 0, fontsize = 12)
plt.yticks(fontsize = 12)
plt.title("First Appeared in the 1970s", fontsize = 16)
plt.xlabel("Sex of Character", fontsize = 14)
plt.ylabel("Number of Characters", fontsize = 14)

plt.show()
# Out:
# Male and Female Superheroes All Years
# Male Characters      16521
# Female Characters     5853
# ND                     978
# Name: SEX, dtype: int64
#
# Superheroes during the 1960s:
# 1791
# Male Characters      1418
# Female Characters     248
# ND                    125
# Name: SEX, dtype: int64
#
# Superheroes during the 1970s:
# 2667
# Male Characters      1999
# Female Characters     527
# ND                    141
# Name: SEX, dtype: int64
